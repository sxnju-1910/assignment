# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("titanic_dataset.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data=pd.read_csv('titanic_dataset.csv',index_col='PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
freqgraph=data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
for col in['Age']:
    data[col] = data[col].fillna(data[col].median())

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
Cabin_mode=data['Cabin'].mode()[0]

# %%
Cabin_mode
# Out:
# 'B96 B98'

# %%
data['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
data['Cabin']=data['Cabin'].fillna(Cabin_mode)

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    2
# dtype: int64

# %%
Embarked_mode=data['Embarked'].mode()[0]

# %%
Embarked_mode
# Out:
# 'S'

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Embarked']=data['Embarked'].fillna(Cabin_mode)

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
plt.boxplot(data['Age'])
plt.show()

# %%
plt.boxplot(data['Fare'])
plt.show()

# %%
plt.boxplot(data['Parch'])
plt.show()

# %% [markdown]
# # AGE

# %%
Q1 = np.percentile(data['Age'],25,interpolation='midpoint')
Q2 = np.percentile(data['Age'],50,interpolation='midpoint')
Q3 = np.percentile(data['Age'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 22.0
# 28.0
# 35.0

# %%
IQR = Q3-Q1

# %%
print(IQR)
# Out:
# 13.0

# %%
up_lim = Q3+1.5*IQR
low_lim = Q1-1.5*IQR

# %%
print(up_lim)
print(low_lim)
# Out:
# 54.5
# 2.5

# %%
outliers = []
for i in data['Age']:
    if i>up_lim or i<low_lim:
        outliers.append(i)

# %%
outliers
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind = data['Age']>up_lim
data.loc[ind].index
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
data = data.drop([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
            269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
            556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
            830, 852, 880])

# %%
data.head(50)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# 30                  0       3
# 32               1      0          PC 17569  146.5208          B78        C
# 33               0      0            335677    7.7500      B96 B98        Q
# 35               1      0          PC 17604   82.1708      B96 B98        C
# 36               1      0            113789   52.0000      B96 B98        S
# 37               0      0              2677    7.2292      B96 B98        C
# 38               0      0        A./5. 2152    8.0500      B96 B98        S
# 39               2      0            345764   18.0000      B96 B98        S
# 40               1      0              2651   11.2417      B96 B98        C
# 41               1      0              7546    9.4750      B96 B98        S
# 42               1      0             11668   21.0000      B96 B98        S
# 43               0      0            349253    7.8958      B96 B98        C
# 44               1      2     SC/Paris 2123   41.5792      B96 B98        C
# 45               0      0            330958    7.8792      B96 B98        Q
# 46               0      0   S.C./A.4. 23567    8.0500      B96 B98        S
# 47               1      0            370371   15.5000      B96 B98        Q
# 48               0      0             14311    7.7500      B96 B98        Q
# 49               2      0              2662   21.6792      B96 B98        C
# 50               1      0            349237   17.8000      B96 B98        S
# 51               4      1           3101295   39.6875      B96 B98        S
# 52               0      0        A/4. 39886    7.8000      B96 B98        S
# 53               1      0          PC 17572   76.7292          D33        C

# %% [markdown]
# # SibSp

# %%
plt.boxplot(data['SibSp'])
plt.show()

# %%
Q1 = np.percentile(data['SibSp'],25,interpolation='midpoint')
Q2 = np.percentile(data['SibSp'],50,interpolation='midpoint')
Q3 = np.percentile(data['SibSp'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 0.0
# 1.0

# %%
IQR = Q3-Q1

# %%
print(IQR)
# Out:
# 1.0

# %%
up_lim = Q3+1.5*IQR
low_lim = Q1-1.5*IQR

# %%
print(up_lim)
print(low_lim)
# Out:
# 2.5
# -1.5

# %%
outliers = []
for i in data['SibSp']:
    if i>up_lim or i<low_lim:
        outliers.append(i)

# %%
outliers
# Out:
# [3,
#  4,
#  3,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  3,
#  4,
#  8,
#  4,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  4,
#  8,
#  4,
#  8]

# %%
ind = data['SibSp']>up_lim
data.loc[ind].index
# Out:
# Int64Index([  8,  17,  25,  28,  51,  60,  64,  69,  72,  86,  89, 120, 160,
#             165, 172, 177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342,
#             375, 387, 410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788,
#             793, 814, 820, 825, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %%
data = data.drop([8,  17,  25,  28,  51,  60,  64,  69,  72,  86,  89, 120, 160,
            165, 172, 177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342,
            375, 387, 410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788,
            793, 814, 820, 825, 847, 851, 864])

# %%
data.head(50)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
#
# 33               0      0            335677    7.7500  B96 B98        Q
# 35               1      0          PC 17604   82.1708  B96 B98        C
# 36               1      0            113789   52.0000  B96 B98        S
# 37               0      0              2677    7.2292  B96 B98        C
# 38               0      0        A./5. 2152    8.0500  B96 B98        S
# 39               2      0            345764   18.0000  B96 B98        S
# 40               1      0              2651   11.2417  B96 B98        C
# 41               1      0              7546    9.4750  B96 B98        S
# 42               1      0             11668   21.0000  B96 B98        S
# 43               0      0            349253    7.8958  B96 B98        C
# 44               1      2     SC/Paris 2123   41.5792  B96 B98        C
# 45               0      0            330958    7.8792  B96 B98        Q
# 46               0      0   S.C./A.4. 23567    8.0500  B96 B98        S
# 47               1      0            370371   15.5000  B96 B98        Q
# 48               0      0             14311    7.7500  B96 B98        Q
# 49               2      0              2662   21.6792  B96 B98        C
# 50               1      0            349237   17.8000  B96 B98        S
# 52               0      0        A/4. 39886    7.8000  B96 B98        S
# 53               1      0          PC 17572   76.7292      D33        C
# 54               1      0              2926   26.0000  B96 B98        S
# 56               0      0             19947   35.5000      C52        S
# 57               0      0        C.A. 31026   10.5000  B96 B98        S
# 58               0      0              2697    7.2292  B96 B98        C
# 59               1      2        C.A. 34651   27.7500  B96 B98        S

# %% [markdown]
# # Fare

# %%
plt.boxplot(data['Fare'])
plt.show()

# %%
sns.pairplot(data[['Fare']])

# %%
data[data['Fare']>200].index
# Out:
# Int64Index([119, 259, 300, 312, 378, 381, 528, 558, 680, 690, 701, 717, 731,
#             738, 743, 780],
#            dtype='int64', name='PassengerId')

# %%
data=data.drop([119, 259, 300, 312, 378, 381, 528, 558, 680, 690, 701, 717, 731,738, 743, 780])

# %% [markdown]
# # Min Max scaling

# %%
x=data.drop('Survived',axis=1)

# %%
y=data['Survived']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
num_cols=['Pclass','Age','SibSp','Parch','Fare']

# %%
min_max=MinMaxScaler(feature_range=(0,1))

# %%
x.loc[:,num_cols]=min_max.fit_transform(x.loc[:,num_cols])
x.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1               1.0                            Braund, Mr. Owen Harris
# 2               0.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3               1.0                             Heikkinen, Miss. Laina
# 4               0.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5               1.0                           Allen, Mr. William Henry
#
#                 Sex       Age  SibSp  Parch            Ticket      Fare  \
# PassengerId
# 1              male  0.402762    0.5    0.0         A/5 21171  0.043975
# 2            female  0.701381    0.5    0.0          PC 17599  0.432369
# 3            female  0.477417    0.0    0.0  STON/O2. 3101282  0.048069
# 4            female  0.645390    0.5    0.0            113803  0.322078
# 5              male  0.645390    0.0    0.0            373450  0.048827
#
#                Cabin Embarked
# PassengerId
# 1            B96 B98        S
# 2                C85        C
# 3            B96 B98        S
# 4               C123        S
# 5            B96 B98        S

# %%
x.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  787.000000  787.000000  787.000000  787.000000  787.000000
# mean     0.672808    0.523784    0.161372    0.051885    0.153285
# std      0.405901    0.196396    0.266935    0.127603    0.177285
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.421426    0.000000    0.000000    0.047892
# 50%      1.000000    0.514744    0.000000    0.000000    0.078852
# 75%      1.000000    0.626726    0.500000    0.000000    0.161039
# max      1.000000    1.000000    1.000000    1.000000    1.000000
