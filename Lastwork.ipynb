# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('beer-servings.csv')
data = pd.read_csv('auto-mpg.csv')

# %%
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan            0.0              0.0            0.0
# 1           1      Albania           89.0            132.0           54.0
# 2           2      Algeria           25.0              0.0           14.0
# 3           3      Andorra          245.0            138.0          312.0
# 4           4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
df.shape
# Out:
# (173, 7)

# %%
df.describe()
# Out:
#        Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# count  173.000000      173.00000       173.000000     173.000000
# mean    95.208092      107.66474        83.965318      49.560694
# std     55.720780      102.45948        91.252454      78.305106
# min      0.000000        0.00000         0.000000       0.000000
# 25%     47.000000       20.00000         3.000000       1.000000
# 50%     95.000000       77.00000        56.000000       9.000000
# 75%    143.000000      192.00000       133.000000      59.000000
# max    192.000000      376.00000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    173.000000
# mean                       4.763584
# std                        3.861121
# min                        0.000000
# 25%                        1.100000
# 50%                        4.400000
# 75%                        7.200000
# max                       14.400000

# %%
# %matplotlib inline
plt.subplot() #creating a fig as subplot
plt.show()

# %%
df.plot()
# Out:
# <AxesSubplot:>
